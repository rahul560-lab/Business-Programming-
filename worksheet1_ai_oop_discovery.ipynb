# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul560-lab/Business-Programming-/blob/main/worksheet1_ai_oop_discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: "AI-Assisted OOP Discovery Worksheet"
# subtitle: "Using AI to Explore Object-Oriented Problem Solving"
# format: html
# ---

# %% [markdown]
# # Worksheet 1: AI-Assisted OOP Discovery
#
# **Name:** _Rahul_Naroti_______________ **Date:** _3_May_2026______________
#
# ## Learning Objectives
# By the end of this worksheet, you will:
#
# - Use AI to discover OOP patterns in real business systems
# - Critique and improve AI-generated class designs
# - Understand how OOP solves business problems through hands-on exploration

# %% [markdown]
# ---
#
# ## Part 1: Discovering Objects in Business Systems
#
# ### Task 1.1: AI Business Analysis
# You're going to use AI to analyze how businesses naturally organize around objects. Pick ONE business type from the list below:
#
# **Business Options:** Coffee Shop, Gym, Online Bookstore, Food Delivery Service, Car Rental, Hotel
#
# **Your chosen business:** __Coffee_Shop______________
#
# Now, use AI to explore this business. Try this exact prompt:
#
# > "I'm studying how a [YOUR BUSINESS TYPE] organizes its information. What are the main 'things' this business deals with every day (like customers, products, orders), and for each thing, what details do they need to remember and what tasks do they need to do with that information?"
#
# ```python
# # Paste the AI response here as a comment:
# """
# AI Response:
# """
# AI Response:
#
# A coffee shop deals with several main things every day.
#
# 1. Customer
# Details: name, order history, payment method, and loyalty points.
# Tasks: place orders, make payments, and earn rewards.
#
# 2. Product
# Details: product name, price, size, category, and ingredients.
# Tasks: update price, check availability, and show menu item.
#
# 3. Order
# Details: order number, customer, products ordered, total price, and order status.
# Tasks: calculate total price, confirm payment, and update order status.
#
# 4. Employee
# Details: employee name, role, shift time, and contact details.
# Tasks: take orders, prepare drinks, and serve customers.
#
# 5. Payment
# Details: payment amount, payment method, date, and payment status.
# Tasks: process payment, confirm payment, and record the sale.
#
# These objects help the coffee shop organise its daily work.
# """
#
# """
# ```
#
# ### Task 1.2: Critical Analysis
# Look at the AI's response and answer these questions:
#
# **1. Objects Identified:** List the main "objects" the AI suggested: Customer, Product, Order, Employee, and Payment.
#
# **2. Pattern Recognition:** Do you see the pattern of "things that store information and perform actions"? Give an example: Yes, Each object stores information and performs actions. For example, an Order stores the customer, products, total price, and order status. It also performs actions such as calculating the total price and updating the order status.
#
# **3. Business Logic:** Which of the AI's suggestions seem most important for running this business? Why?
# Order, Product, and Payment are the most important objects. The coffee shop needs products to sell, orders to track customer purchases, and payments to record money received.
#
# ---
#
# ## Part 2: Building Your First Business Class
#
# ### Task 2.1: Transaction Class Design Challenge
#
# You need to design a Transaction class for your Smart Finance App. Instead of starting from scratch, let's use AI as your design assistant.
#
# **Step 1:** Ask AI to design the basic structure:
#
# > "I'm building a personal finance app that needs to track transactions. Each transaction should remember when it happened, what it was for, how much money was involved (with expenses as negative numbers), and what category it belongs to. How would you design a template or blueprint that I could reuse for every transaction?"
#
# ```python
# class Transaction:
#     def __init__(self, date, description, amount, category):
#         self.date = date
#         self.description = description
#         self.amount = amount
#         self.category = category
#
#     def show_transaction(self):
#         return f"{self.date} | {self.description} | {self.amount} | {self.category}"
#
# ```
#
# ### Task 2.2: Critique and Improve
#
# **Step 2:** Now critique the AI's response by testing it:
#
# ```python
# t1 = Transaction("2025-09-20", "Starbucks Coffee", -4.50, "Food")
# t2 = Transaction("2025-09-21", "Salary Deposit", 3000.00, "Income")
# t3 = Transaction("2025-09-22", "Grocery Shopping", -67.85, "Food")
#
# print(t1.show_transaction())
# print(t2.show_transaction())
# print(t3.show_transaction())
#
# ```
#
# **What problems do you notice?** (e.g., formatting, validation, missing features)
#
# **Step 3:** Ask AI to improve based on your findings:
#
# > "I tested my transaction template and found some issues: [LIST YOUR IMPROVEMENTS]. How would you improve the design to handle these problems while keeping it simple for business users?"
#
# ```python
# class Transaction:
#     def __init__(self, date, description, amount, category):
#         self.date = date
#         self.description = description
#         self.amount = float(amount)
#         self.category = category
#
#     def transaction_type(self):
#         if self.amount < 0:
#             return "Expense"
#         else:
#             return "Income"
#
#     def show_transaction(self):
#         return f"{self.date} | {self.description} | ${self.amount:.2f} | {self.category} | {self.transaction_type()}"
#
# ```
#
# ---
#
# ## Part 3: Real-World Problem Solving
#
# ### Task 3.1: The CSV Integration Challenge
#
# Here's a real business problem: You have historical transaction data in a CSV file, but you also need to add new transactions manually. How does your Transaction class solve this?
#
# **Step 1:** Let's create some sample data to work with:
#
# ```python
# # Sample transaction data as if from a CSV
# transaction_data = [
#     {"date": "2025-09-20", "description": "Starbucks Coffee", "amount": -4.50, "category": "Food"},
#     {"date": "2025-09-21", "description": "Salary Deposit", "amount": 3000.00, "category": "Income"},
#     {"date": "2025-09-22", "description": "Grocery Shopping", "amount": -67.85, "category": "Food"},
#     {"date": "2025-09-23", "description": "Gas Station", "amount": -45.00, "category": "Transport"}
# ]
#
# # Print the raw data to see what we're working with
# for transaction in transaction_data:
#     print(transaction)
# ```
#
# **Step 2:** Ask AI how to convert this data to Transaction objects:
#
# > "I have transaction data from a spreadsheet (shown above). How do I turn each row of spreadsheet data into a transaction using my template, so I can work with them consistently?"
#
# ```python
# transactions = []
#
# for row in transaction_data:
#     transaction = Transaction(
#         row["date"],
#         row["description"],
#         row["amount"],
#         row["category"]
#     )
#     transactions.append(transaction)
#
# print("Transactions converted successfully.")
#
# ```
#
# **Step 3:** Test it:
#
# ```python
# for transaction in transactions:
#     print(transaction.show_transaction())
#
# ```
#
# ### Task 3.2: Adding Business Logic
#
# Now let's add some business intelligence. Ask AI to help:
#
# > "I want my transaction template to be smarter. It should be able to tell me: 1) If a transaction is a large expense (over $50), 2) How to display it nicely for business reports, and 3) Whether it happened this month. How would you add these business features?"
#
# ```python
# # Enhanced Transaction class with business logic: The improved Transaction class adds business logic. It checks whether a transaction is a large expense, displays the transaction in a clearer report format, and checks whether the transaction happened in the selected month. This makes the class more useful because it stores data and also helps with basic finance analysis.
#
# ```
#
# Test the new methods:
#
# ```python
# # Test the enhanced methods:
#
# ```
#
# ---
#
# ## Part 4: System-Level Thinking
#
# ### Task 4.1: The Manager Class Challenge
#
# Individual transactions are useful, but businesses need to analyze collections of transactions. This is where system-level objects come in.
#
# Ask AI to design a system:
#
# > "I have individual transactions working well, but I need a system to manage hundreds of them for business reporting. I need to calculate total expenses, group spending by category, and find the biggest purchases. How would you design a 'transaction manager' system that organizes all my individual transactions?"
#
# ```python
# # AI's TransactionManager design:
#
# ```
#
# ### Task 4.2: Integration Testing
#
# Let's see how individual objects and system objects work together:
#
# ```python
# # Create a TransactionManager and add your Transaction objects to it:
#
# ```
#
# ```python
# # Test the business analysis methods:
#
# ```
#
# ---
#
# ## Part 5: Reflection and Real-World Connections
#
# ### Task 5.1: Problem-Solving Analysis
#
# **1. Business Problem Solved:** How did using objects solve the problem of managing both CSV data and individual transactions?
# Using objects helped manage CSV data and manual transactions in the same way. Each row from the CSV became a Transaction object, and each manual entry also became a Transaction object. This made the data easier to store, display, and analyse.
#
# **2. Scalability:** How would your solution handle 1,000 transactions instead of 4?
# The same design would still work with 1,000 transactions. The TransactionManager stores all transactions in a list and loops through them for totals, category spending, and biggest purchases. For a larger real app, the data would be stored in a database instead of only a list.
#
# **3. Real-World Application:** Name a business system you use (banking app, shopping app, etc.) that probably uses this same pattern of individual objects + manager objects: A banking app uses this same pattern. Each payment or deposit is like a Transaction object, and the app uses a manager system to calculate balances, spending categories, and account summaries.
#
# ### Task 5.2: AI Collaboration Reflection
#
# **1. AI Strengths:** What did AI do well in helping you design these classes?
# AI helped create the first class design and gave useful ideas for methods, such as showing transactions, checking large expenses, and grouping spending by category.
#
# **2. AI Limitations:** Where did you need to guide or correct the AI?
# AI needed guidance to keep the code simple and suitable for business users. Some parts also needed testing to check formatting and whether the output made sense.
# **3. Human Value:** What parts required your business understanding rather than just code generation?
# The human role was important for choosing the business problem, deciding which features were useful, checking the output, and making sure the design matched the finance app purpose.
#
# ---
#
# ## Extension Challenge (Optional)
#
# If you finish early, try this advanced challenge:
#
# > "I want my transaction manager to work with both spreadsheet files and manually entered data. How would you design it so I can load existing data from CSV files and also add new transactions one at a time, with everything working together seamlessly?"
#
# ```python
# # Advanced CSV integration:
#
# ```
#
# ---
#
# ## Key Takeaways
#
# By completing this worksheet, you've discovered:
#
# - How AI can help you explore and design object-oriented solutions
# - How classes provide templates for organising business data
# - How individual objects and system objects work together
# - How OOP solves real business problems like data integration and analysis
# - The importance of human oversight in AI-assisted development
#
# **Most importantly:** You've learned that OOP is not about memorizing syntax - it's about organising solutions to business problems in a way that mirrors how businesses actually work.

# %%
print("Total expenses:", manager.total_expenses())
print("Spending by category:", manager.spending_by_category())
print("Biggest purchase:", manager.biggest_purchase())
# Out:
# Total expenses: -117.35
# Spending by category: {'Food': -72.35, 'Transport': -45.0}
# Biggest purchase: 2025-09-22 | Grocery Shopping | $-67.85 | Food | Expense

# %%
manager = TransactionManager()

for transaction in transactions:
    manager.add_transaction(transaction)

print("Transactions added to manager.")
# Out:
# Transactions added to manager.

# %%
class TransactionManager:
    def __init__(self):
        self.transactions = []

    def add_transaction(self, transaction):
        self.transactions.append(transaction)

    def total_expenses(self):
        total = 0
        for transaction in self.transactions:
            if transaction.amount < 0:
                total += transaction.amount
        return total

    def spending_by_category(self):
        categories = {}

        for transaction in self.transactions:
            if transaction.amount < 0:
                if transaction.category not in categories:
                    categories[transaction.category] = 0
                categories[transaction.category] += transaction.amount

        return categories

    def biggest_purchase(self):
        expenses = []

        for transaction in self.transactions:
            if transaction.amount < 0:
                expenses.append(transaction)

        if len(expenses) == 0:
            return "No expenses found."

        biggest = min(expenses, key=lambda t: t.amount)
        return biggest.show_transaction()

# %%
t1 = Transaction("2025-09-20", "Starbucks Coffee", -4.50, "Food")
t2 = Transaction("2025-09-22", "Grocery Shopping", -67.85, "Food")
t3 = Transaction("2025-09-23", "Gas Station", -45.00, "Transport")

print(t1.display_report())
print("Large expense:", t1.is_large_expense())
print("This month:", t1.happened_this_month())

print()

print(t2.display_report())
print("Large expense:", t2.is_large_expense())
print("This month:", t2.happened_this_month())

print()

print(t3.display_report())
print("Large expense:", t3.is_large_expense())
print("This month:", t3.happened_this_month())
# Out:
# Date: 2025-09-20, Description: Starbucks Coffee, Amount: $-4.50, Category: Food, Type: Expense
# Large expense: False
# This month: True
#
# Date: 2025-09-22, Description: Grocery Shopping, Amount: $-67.85, Category: Food, Type: Expense
# Large expense: True
# This month: True
#
# Date: 2025-09-23, Description: Gas Station, Amount: $-45.00, Category: Transport, Type: Expense
# Large expense: False
# This month: True

# %%
from datetime import datetime

class Transaction:
    def __init__(self, date, description, amount, category):
        self.date = date
        self.description = description
        self.amount = float(amount)
        self.category = category

    def transaction_type(self):
        if self.amount < 0:
            return "Expense"
        else:
            return "Income"

    def is_large_expense(self):
        return self.amount < -50

    def display_report(self):
        return f"Date: {self.date}, Description: {self.description}, Amount: ${self.amount:.2f}, Category: {self.category}, Type: {self.transaction_type()}"

    def happened_this_month(self, year=2025, month=9):
        transaction_date = datetime.strptime(self.date, "%Y-%m-%d")
        return transaction_date.year == year and transaction_date.month == month

    def show_transaction(self):
        return f"{self.date} | {self.description} | ${self.amount:.2f} | {self.category} | {self.transaction_type()}"

# %%
transaction_data = [
    {"date": "2025-09-20", "description": "Starbucks Coffee", "amount": -4.50, "category": "Food"},
    {"date": "2025-09-21", "description": "Salary Deposit", "amount": 3000.00, "category": "Income"},
    {"date": "2025-09-22", "description": "Grocery Shopping", "amount": -67.85, "category": "Food"},
    {"date": "2025-09-23", "description": "Gas Station", "amount": -45.00, "category": "Transport"}
]

for transaction in transaction_data:
    print(transaction)
# Out:
# {'date': '2025-09-20', 'description': 'Starbucks Coffee', 'amount': -4.5, 'category': 'Food'}
# {'date': '2025-09-21', 'description': 'Salary Deposit', 'amount': 3000.0, 'category': 'Income'}
# {'date': '2025-09-22', 'description': 'Grocery Shopping', 'amount': -67.85, 'category': 'Food'}
# {'date': '2025-09-23', 'description': 'Gas Station', 'amount': -45.0, 'category': 'Transport'}

# %%
class Transaction:
    def __init__(self, date, description, amount, category):
        self.date = date
        self.description = description
        self.amount = float(amount)
        self.category = category

    def transaction_type(self):
        if self.amount < 0:
            return "Expense"
        else:
            return "Income"

    def show_transaction(self):
        return f"{self.date} | {self.description} | ${self.amount:.2f} | {self.category} | {self.transaction_type()}"

t1 = Transaction("2025-09-20", "Starbucks Coffee", -4.50, "Food")
t2 = Transaction("2025-09-21", "Salary Deposit", 3000.00, "Income")

print(t1.show_transaction())
print(t2.show_transaction())
# Out:
# 2025-09-20 | Starbucks Coffee | $-4.50 | Food | Expense
# 2025-09-21 | Salary Deposit | $3000.00 | Income | Income

# %%
transactions = []

for row in transaction_data:
    transaction = Transaction(
        row["date"],
        row["description"],
        row["amount"],
        row["category"]
    )
    transactions.append(transaction)

for transaction in transactions:
    print(transaction.show_transaction())
# Out:
# 2025-09-20 | Starbucks Coffee | $-4.50 | Food | Expense
# 2025-09-21 | Salary Deposit | $3000.00 | Income | Income
# 2025-09-22 | Grocery Shopping | $-67.85 | Food | Expense
# 2025-09-23 | Gas Station | $-45.00 | Transport | Expense
